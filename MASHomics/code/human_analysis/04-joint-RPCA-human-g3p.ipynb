# %% [markdown]
# ### joint-RPCA (for human MAFLD)

# %%
biom convert \
 -i /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/data/human_analysis/caussy_nafld_16s/m16S_counts_g1pg3p_jrpca_microhits.txt \
 -o /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/data/human_analysis/caussy_nafld_16s/m16S_counts_g1pg3p_jrpca_microhits.biom \
 --table-type="OTU table" \
 --to-hdf5

qiime tools import \
 --input-path /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/data/human_analysis/caussy_nafld_16s/m16S_counts_g1pg3p_jrpca_microhits.biom \
 --output-path /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/data/human_analysis/caussy_nafld_16s/m16S_counts_g1pg3p_jrpca_microhits.qza \
 --type FeatureTable[Frequency]

biom convert \
 -i /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/data/human_analysis/caussy_nafld_mtb/mtb_counts_g1pg3p_jrpca_mousehits.txt \
 -o /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/data/human_analysis/caussy_nafld_mtb/mtb_counts_g1pg3p_jrpca_mousehits.biom \
 --table-type="OTU table" \
 --to-hdf5

qiime tools import \
 --input-path /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/data/human_analysis/caussy_nafld_mtb/mtb_counts_g1pg3p_jrpca_mousehits.biom \
 --output-path /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/data/human_analysis/caussy_nafld_mtb/mtb_counts_g1pg3p_jrpca_mousehits.qza \
 --type FeatureTable[Frequency]

# %%
qiime gemelli joint-rpca \
    --i-tables /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/data/human_analysis/caussy_nafld_mtb/mtb_counts_g1pg3p_jrpca_mousehits.qza /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/data/human_analysis/caussy_nafld_16s/m16S_counts_g1pg3p_jrpca_microhits.qza \
    --m-sample-metadata-file /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/data/human_analysis/caussy_nafld_16s/metadata_jrpca.txt \
    --p-train-test-column  'traintest' \
    --p-max-iterations 25 \
    --p-min-feature-frequency 5 \
    --o-biplot /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/results/human_analysis/jrpca/result_microhits_mouse/joint_biplot.qza\
    --o-distance-matrix /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/results/human_analysis/jrpca/result_microhits_mouse/joint_distance_matrix.qza\
    --o-cross-validation-error /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/results/human_analysis/jrpca/result_microhits_mouse/cross_validation_error.qza

# %%
qiime longitudinal volatility \
    --m-metadata-file /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/results/human_analysis/jrpca/result_microhits_mouse/cross_validation_error.qza \
    --p-state-column 'iteration' \
    --o-visualization /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/results/human_analysis/jrpca/result_microhits_mouse/volatility_plot.qzv

# %%
qiime emperor biplot \
    --i-biplot /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/results/human_analysis/jrpca/result_microhits_mouse/joint_biplot.qza \
    --m-sample-metadata-file /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/data/human_analysis/caussy_nafld_16s/metadata_jrpca.txt \
    --p-number-of-features 25 \
    --o-visualization /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/results/human_analysis/jrpca/result_microhits_mouse/emperor-biplot.qzv

# %%
qiime diversity beta-group-significance \
    --i-distance-matrix /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/results/human_analysis/jrpca/result_microhits_mouse/joint_distance_matrix.qza \
    --m-metadata-file /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/data/human_analysis/caussy_nafld_16s/metadata_jrpca.txt \
    --m-metadata-column 'groups'\
    --p-pairwise \
    --o-visualization /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/results/human_analysis/jrpca/result_microhits_mouse/permanova-groups.qzv

# %%
qiime gemelli feature-correlation-table \
    --i-ordination /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/results/human_analysis/jrpca/result_microhits_mouse/joint_biplot.qza \
    --o-correlation-table /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/results/human_analysis/jrpca/result_microhits_mouse/correlation_table.qza

# %%
qiime tools export --input-path /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/results/human_analysis/jrpca/result_microhits_mouse/correlation_table.qza \
--output-path /mnt/zarrinpar/Pynchon/Notebooks/sfloresr/MASH-TRF/MASHomics/results/human_analysis/jrpca/result_microhits_mouse/correlation_table
